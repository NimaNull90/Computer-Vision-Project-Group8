# %% [markdown]
# <a href="https://colab.research.google.com/github/NimaNull90/Computer-Vision-Project-Group8/blob/101BPY/untitled8_50epochtest_v1v2Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ultralytics
from ultralytics import YOLO
# %matplotlib inline
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 73.3 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8s.pt')  # pretrained YOLOv8 small

model.train(
    data="/content/drive/MyDrive/Data/data/data.yaml",
    epochs=50,
    imgsz=640,
    batch=8,
    lr0=0.0005,
    name="solar_panel_v1"
)
# Out:
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-80GB, 81222MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
metrics = model.val()

print(f"mAP50: {metrics.box.map50:.4f}")
print(f"mAP50-95: {metrics.box.map:.4f}")
print(f"Precision: {metrics.box.mp:.4f}")
print(f"Recall: {metrics.box.mr:.4f}")

P, R = metrics.box.mp, metrics.box.mr
F1 = 2 * P * R / (P + R) if (P + R) > 0 else 0
print(f"F1-score: {F1:.4f}")
# Out:
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-80GB, 81222MiB)
# Model summary (fused): 72 layers, 11,128,293 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 42.3±11.8 MB/s, size: 81.0 KB)
# val: Scanning /content/drive/MyDrive/Data/data/labels/val.cache... 358 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 358/358 446.1Kit/s 0.0s
# val: /content/drive/MyDrive/Data/data/images/val/Dusty_89_jpg.rf.32df8e09f4a019c13101888ee6c04d8d.jpg: 1 duplicate labels removed
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2070, len(boxes) = 2467. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 4.9it/s 4.7s
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os
import glob

# Find the latest run directory for v1 model
runs_dir = "/content/runs/detect"
v1_run_dirs = sorted(glob.glob(os.path.join(runs_dir, "solar_panel_v1*")))
if v1_run_dirs:
    result_dir = v1_run_dirs[-1]
else:
    result_dir = "/content/runs/detect/solar_panel_v1" # Fallback, though likely to fail if no runs found

img1 = Image.open(f"{result_dir}/results.png")
img2 = Image.open(f"{result_dir}/confusion_matrix.png")

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img1)
plt.axis('off')
plt.title('Training Results')

plt.subplot(1,2,2)
plt.imshow(img2)
plt.axis('off')
plt.title('Confusion Matrix')

plt.tight_layout()
plt.show()

# %%
metrics_test = model.val(
    data="/content/drive/MyDrive/Data/data/data.yaml",
    split="test"
)

print("----- TEST RESULTS -----")
print(f"mAP50: {metrics_test.box.map50:.4f}")
print(f"mAP50-95: {metrics_test.box.map:.4f}")
print(f"Precision: {metrics_test.box.mp:.4f}")
print(f"Recall: {metrics_test.box.mr:.4f}")

P, R = metrics_test.box.mp, metrics_test.box.mr
F1 = 2 * P * R / (P + R) if (P + R) > 0 else 0
print(f"F1-score: {F1:.4f}")
# Out:
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-80GB, 81222MiB)
# val: Fast image access ✅ (ping: 0.5±0.2 ms, read: 0.3±0.3 MB/s, size: 224.6 KB)
# val: Scanning /content/drive/MyDrive/Data/data/labels/test.cache... 60 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 60/60 78.3Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.1it/s 30.8s
#                    all         60         74     0.0543     0.0541     0.0205    0.00622
#        Physical-Damage         60         74     0.0543     0.0541     0.0205    0.00622
# Speed: 2.8ms preprocess, 13.6ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /content/runs/detect/val2
# ----- TEST RESULTS -----
# mAP50: 0.0205
# mAP50-95: 0.0062
# Precision: 0.0543
# Recall: 0.0541
# F1-score: 0.0542

# %%
model = YOLO('yolov8s.pt')

model.train(
    data='/content/drive/MyDrive/Data/data/data.yaml',
    epochs=50,
    imgsz=640,
    batch=8,
    lr0=0.001,          # changed to 0.001
    name='solar_panel_v2'
)
# Out:
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-80GB, 81222MiB)
# ...

# %%
results = model('/content/drive/MyDrive/Data/data/images/test/physical1.jpg', save=True)
results = model('/content/drive/MyDrive/Data/data/images/test/physical25.jpg', save=True)
# Out:
# image 1/1 /content/drive/MyDrive/Data/data/images/test/physical1.jpg: 384x640 1 Clean, 1 Physical-Damage, 2 Snow-Covereds, 74.1ms
# Speed: 1.6ms preprocess, 74.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict
#
# image 1/1 /content/drive/MyDrive/Data/data/images/test/physical25.jpg: 640x640 2 Cleans, 3 Physical-Damages, 8.2ms
# Speed: 2.3ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict

# %%
from ultralytics import YOLO
import glob
import os

# Find the latest run directory for v1 model
runs_dir = "/content/runs/detect"
v1_run_dirs = sorted(glob.glob(os.path.join(runs_dir, "solar_panel_v1*")))
if v1_run_dirs:
    v1_latest_run_dir = v1_run_dirs[-1]
    v1_weights = os.path.join(v1_latest_run_dir, "weights/best.pt")
else:
    v1_weights = "/content/runs/detect/solar_panel_v1/weights/best.pt" # Fallback, though likely to fail if no runs found

model_v1 = YOLO(v1_weights)

metrics_v1_test = model_v1.val(
    data="/content/drive/MyDrive/Data/data/data.yaml",
    split="test"
)
P1, R1 = float(metrics_v1_test.box.mp), float(metrics_v1_test.box.mr)
F11 = 2*P1*R1/(P1+R1) if (P1+R1)>0 else 0.0

print("[V1 TEST] mAP50-95:", float(metrics_v1_test.box.map))
print("[V1 TEST] mAP50:", float(metrics_v1_test.box.map50))
print("[V1 TEST] Precision:", P1)
print("[V1 TEST] Recall:", R1)
print("[V1 TEST] F1:", F11)
# Out:
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-80GB, 81222MiB)
# Model summary (fused): 72 layers, 11,128,293 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 145.9±146.5 MB/s, size: 269.6 KB)
# val: Scanning /content/drive/MyDrive/Data/data/labels/test.cache... 60 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 60/60 99.1Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.6it/s 1.6s
#                    all         60         74     0.0543     0.0541     0.0205    0.00622
#        Physical-Damage         60         74     0.0543     0.0541     0.0205    0.00622
# Speed: 2.3ms preprocess, 1.1ms inference, 0.0ms loss, 8.6ms postprocess per image
# Results saved to /content/runs/detect/val3
# [V1 TEST] mAP50-95: 0.006216395841770068
# [V1 TEST] mAP50: 0.020474798227335847
# [V1 TEST] Precision: 0.0542683477689915
# ...

# %%
v2_weights = "/content/runs/detect/solar_panel_v2/weights/best.pt"
model_v2 = YOLO(v2_weights)

metrics_v2_test = model_v2.val(
    data="/content/drive/MyDrive/Data/data/data.yaml",
    split="test"
)
P2, R2 = float(metrics_v2_test.box.mp), float(metrics_v2_test.box.mr)
F12 = 2*P2*R2/(P2+R2) if (P2+R2)>0 else 0.0

print("[V2 TEST] mAP50-95:", float(metrics_v2_test.box.map))
print("[V2 TEST] mAP50:", float(metrics_v2_test.box.map50))
print("[V2 TEST] Precision:", P2)
print("[V2 TEST] Recall:", R2)
print("[V2 TEST] F1:", F12)

# show compare table
print("\n=== TEST Comparison (V1 vs V2) ===")
print(f"{'Model':<10}{'lr0':<10}{'Epochs':<8}{'mAP50':<10}{'P':<10}{'R':<10}{'F1':<10}")
print(f"{'v1':<10}{'0.0005':<10}{'10':<8}{metrics_v1_test.box.map50:.4f}    {P1:.4f}    {R1:.4f}    {F11:.4f}")
print(f"{'v2':<10}{'0.001':<10}{'10':<8}{metrics_v2_test.box.map50:.4f}    {P2:.4f}    {R2:.4f}    {F12:.4f}")
# Out:
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-80GB, 81222MiB)
# Model summary (fused): 72 layers, 11,128,293 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 64.2±32.6 MB/s, size: 101.9 KB)
# val: Scanning /content/drive/MyDrive/Data/data/labels/test.cache... 60 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 60/60 83.0Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.5it/s 1.6s
#                    all         60         74     0.0609     0.0676     0.0201    0.00639
#        Physical-Damage         60         74     0.0609     0.0676     0.0201    0.00639
# Speed: 2.7ms preprocess, 1.4ms inference, 0.0ms loss, 3.6ms postprocess per image
# Results saved to /content/runs/detect/val4
# [V2 TEST] mAP50-95: 0.006389097797824117
# [V2 TEST] mAP50: 0.020105817483126835
# [V2 TEST] Precision: 0.060919136357608504
# ...

# %%
import os, random

test_img_dir = "/content/drive/MyDrive/Data/data/images/test"
sample_imgs = random.sample([f for f in os.listdir(test_img_dir) if f.lower().endswith(('.jpg','.jpeg','.png'))], k=min(6, len(os.listdir(test_img_dir))))

# Save prediction images using the v1 model
pred_dir_v1 = "/content/runs/detect/solar_panel_v1_pred"
_ = model_v1.predict(source=[os.path.join(test_img_dir, f) for f in sample_imgs], save=True, name=os.path.basename(pred_dir_v1))

# Save prediction images using the v2 model
pred_dir_v2 = "/content/runs/detect/solar_panel_v2_pred"
_ = model_v2.predict(source=[os.path.join(test_img_dir, f) for f in sample_imgs], save=True, name=os.path.basename(pred_dir_v2))

print("Saved sample predictions to:")
print(pred_dir_v1)
print(pred_dir_v2)
# Out:
# 0: 640x640 1 Clean, 1 Dusty, 13.4ms
# 1: 640x640 5 Dustys, 1 Physical-Damage, 3 Snow-Covereds, 13.4ms
# 2: 640x640 1 Clean, 2 Physical-Damages, 13.4ms
# 3: 640x640 1 Clean, 1 Physical-Damage, 13.4ms
# 4: 640x640 17 Bird-drops, 1 Clean, 1 Snow-Covered, 13.4ms
# 5: 640x640 1 Dusty, 13.4ms
# Speed: 2.7ms preprocess, 13.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/solar_panel_v1_pred
#
# 0: 640x640 2 Cleans, 1.4ms
# 1: 640x640 5 Dustys, 1 Physical-Damage, 4 Snow-Covereds, 1.4ms
# 2: 640x640 1 Clean, 2 Physical-Damages, 1.4ms
# 3: 640x640 1 Clean, 1 Physical-Damage, 1.4ms
# 4: 640x640 16 Bird-drops, 2 Cleans, 1 Snow-Covered, 1.4ms
# 5: 640x640 1 Dusty, 1.4ms
# Speed: 2.5ms preprocess, 1.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/solar_panel_v2_pred
# Saved sample predictions to:
# /content/runs/detect/solar_panel_v1_pred
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os
import glob

runs_dir = "/content/runs/detect"

# Find the latest *training* run directory for v1 model, excluding prediction directories
v1_run_dirs = sorted([d for d in glob.glob(os.path.join(runs_dir, "solar_panel_v1*")) if "pred" not in d])
if v1_run_dirs:
    v1_result_dir = v1_run_dirs[-1]
else:
    v1_result_dir = os.path.join(runs_dir, "solar_panel_v1") # Fallback, though likely to fail if no runs found

# Find the latest *training* run directory for v2 model, excluding prediction directories
v2_run_dirs = sorted([d for d in glob.glob(os.path.join(runs_dir, "solar_panel_v2*")) if "pred" not in d])
if v2_run_dirs:
    v2_result_dir = v2_run_dirs[-1]
else:
    v2_result_dir = os.path.join(runs_dir, "solar_panel_v2") # Fallback, though likely to fail if no runs found


plt.figure(figsize=(12,8))
plt.subplot(2,2,1); plt.imshow(Image.open(f"{v1_result_dir}/results.png")); plt.axis('off'); plt.title('V1 Training Results')
plt.subplot(2,2,2); plt.imshow(Image.open(f"{v1_result_dir}/confusion_matrix.png")); plt.axis('off'); plt.title('V1 Confusion Matrix')
plt.subplot(2,2,3); plt.imshow(Image.open(f"{v2_result_dir}/results.png")); plt.axis('off'); plt.title('V2 Training Results')
plt.subplot(2,2,4); plt.imshow(Image.open(f"{v2_result_dir}/confusion_matrix.png")); plt.axis('off'); plt.title('V2 Confusion Matrix')
plt.tight_layout(); plt.show()

# %%
# %matplotlib inline
from PIL import Image
import matplotlib.pyplot as plt


img_path = '/content/runs/detect/predict/physical25.jpg'


img = Image.open(img_path)
plt.imshow(img)
plt.axis('off')
plt.title('Prediction Result - solar_panel_v1')
plt.show()
